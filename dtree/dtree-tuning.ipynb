# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.utils import check_random_state
from sklearn.preprocessing import StandardScaler
from xgboost import callback
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np
import optuna
import pickle
from sklearn.metrics import mean_squared_error
import joblib 
import os
from sklearn.tree import DecisionTreeRegressor
def cov2corr(cov):
    # Derive the correlation matrix from a covariance matrix
    std = np.sqrt(np.diag(cov))
    corr = cov/np.outer(std,std)
    corr[corr<-1], corr[corr>1] = -1,1 #for numerical errors
    return corr

def clusterKMeansBase(corr0, maxNumClusters=10, n_init=10, debug=False):
    corr0[corr0 > 1] = 1
    dist_matrix = ((1-corr0)/2.)**.5
    silh_coef_optimal = pd.Series(dtype='float64') #observations matrixs
    kmeans, stat = None, None
    maxNumClusters = min(maxNumClusters, int(np.floor(dist_matrix.shape[0]/2)))
    print("maxNumClusters"+str(maxNumClusters))
    for init in range(0, n_init):
    #The [outer] loop repeats the first loop multiple times, thereby obtaining different initializations. Ref: de Prado and Lewis (2018)
    #DETECTION OF FALSE INVESTMENT STRATEGIES USING UNSUPERVISED LEARNING METHODS
        for num_clusters in range(2, maxNumClusters+1):
            #(maxNumClusters + 2 - num_clusters) # go in reverse order to view more sub-optimal solutions
            kmeans_ = KMeans(n_clusters=num_clusters, n_init=10) #, random_state=3425) #n_jobs=None #n_jobs=None - use all CPUs
            kmeans_ = kmeans_.fit(dist_matrix)
            silh_coef = silhouette_samples(dist_matrix, kmeans_.labels_)
            stat = (silh_coef.mean()/silh_coef.std(), silh_coef_optimal.mean()/silh_coef_optimal.std())

            # If this metric better than the previous set as the optimal number of clusters
            if np.isnan(stat[1]) or stat[0] > stat[1]:
                silh_coef_optimal = silh_coef
                kmeans = kmeans_
                if debug==True:
                    print(kmeans)
                    print(stat)
                    silhouette_avg = silhouette_score(dist_matrix, kmeans_.labels_)
                    print("For n_clusters ="+ str(num_clusters)+ "The average silhouette_score is :"+ str(silhouette_avg))
                    print("********")

    newIdx = np.argsort(kmeans.labels_)
    #print(newIdx)

    corr1 = corr0.iloc[newIdx] #reorder rows
    corr1 = corr1.iloc[:, newIdx] #reorder columns

    clstrs = {i:corr0.columns[np.where(kmeans.labels_==i)[0]].tolist() for i in np.unique(kmeans.labels_)} #cluster members
    silh_coef_optimal = pd.Series(silh_coef_optimal, index=dist_matrix.index)

    return corr1, clstrs, silh_coef_optimal

def makeNewOutputs(corr0, clstrs, clstrs2):
    clstrsNew, newIdx = {}, []
    for i in clstrs.keys():
        clstrsNew[len(clstrsNew.keys())] = list(clstrs[i])

    for i in clstrs2.keys():
        clstrsNew[len(clstrsNew.keys())] = list(clstrs2[i])

    newIdx = [j for i in clstrsNew for j in clstrsNew[i]]
    corrNew = corr0.loc[newIdx, newIdx]

    dist = ((1 - corr0) / 2.)**.5
    kmeans_labels = np.zeros(len(dist.columns))
    for i in clstrsNew.keys():
        idxs = [dist.index.get_loc(k) for k in clstrsNew[i]]
        kmeans_labels[idxs] = i

    silhNew = pd.Series(silhouette_samples(dist, kmeans_labels), index=dist.index)

    return corrNew, clstrsNew, silhNew

def clusterKMeansTop(corr0: pd.DataFrame, maxNumClusters=None, n_init=10):
    if maxNumClusters == None:
        maxNumClusters = corr0.shape[1]-1

    corr1, clstrs, silh = clusterKMeansBase(corr0, maxNumClusters=min(maxNumClusters, corr0.shape[1]-1), n_init=10)#n_init)
    print("clstrs length:"+str(len(clstrs.keys())))
    print("best clustr:"+str(len(clstrs.keys())))
    #for i in clstrs.keys():
    #    print("std:"+str(np.std(silh[clstrs[i]])))

    clusterTstats = {i:np.mean(silh[clstrs[i]])/np.std(silh[clstrs[i]]) for i in clstrs.keys()}
    tStatMean = np.sum(list(clusterTstats.values()))/len(clusterTstats)
    redoClusters = [i for i in clusterTstats.keys() if clusterTstats[i] < tStatMean]
    #print("redo cluster:"+str(redoClusters))
    if len(redoClusters) <= 2:
        print("If 2 or less clusters have a quality rating less than the average then stop.")
        print("redoCluster <=1:"+str(redoClusters)+" clstrs len:"+str(len(clstrs.keys())))
        return corr1, clstrs, silh
    else:
        keysRedo = [j for i in redoClusters for j in clstrs[i]]
        corrTmp = corr0.loc[keysRedo, keysRedo]
        _, clstrs2, _ = clusterKMeansTop(corrTmp, maxNumClusters=min(maxNumClusters, corrTmp.shape[1]-1), n_init=n_init)
        print("clstrs2.len, stat:"+str(len(clstrs2.keys())))
        #Make new outputs, if necessary
        dict_redo_clstrs = {i:clstrs[i] for i in clstrs.keys() if i not in redoClusters}
        corrNew, clstrsNew, silhNew = makeNewOutputs(corr0, dict_redo_clstrs, clstrs2)
        newTstatMean = np.mean([np.mean(silhNew[clstrsNew[i]])/np.std(silhNew[clstrsNew[i]]) for i in clstrsNew.keys()])
        if newTstatMean <= tStatMean:
            print("newTstatMean <= tStatMean"+str(newTstatMean)+ " (len:newClst)"+str(len(clstrsNew.keys()))+" <= "+str(tStatMean)+ " (len:Clst)"+str(len(clstrs.keys())))
            return corr1, clstrs, silh
        else:
            print("newTstatMean > tStatMean"+str(newTstatMean)+ " (len:newClst)"+str(len(clstrsNew.keys()))
                  +" > "+str(tStatMean)+ " (len:Clst)"+str(len(clstrs.keys())))
            return corrNew, clstrsNew, silhNew
            #return corr1, clstrs, silh, stat

def choose_position(roi, trade_threshold = 0.01):
    pos =0
    # Predict position base on change in future
    if roi > trade_threshold:
        pos = 1
    elif roi < -trade_threshold:
        pos = -1
    else:
        pos = 0

    return pos

def backtest_position_ps(position, price, periods, percentage=0.01):
    #print(periods)
    # Shift positions to align with future price changes and handle NaN by filling with 0
    pos = pd.Series(position, index=pd.Series(price).index).shift(1).fillna(0)
    pos = pd.Series(pos).rolling(int(periods)).sum() #pos for 10 hour predict

    price_array = pd.Series(price).shift(1).fillna(0)

    pos_diff = pos.diff()
    fee = pos_diff*price_array*0.05*percentage

    # Calculate price changes over the given periods
    ch = pd.Series(price) - price_array

    # Calculate total PnL
    total_pnl = pos*ch - fee
    return total_pnl

def calculate_sharpe_ratio(pnl):
    pnl = np.diff(pnl)
    std = np.std(pnl) if np.std(pnl) != 0 else 0.001
    sharpe = np.mean(pnl)/std*np.sqrt(252)
    return sharpe

def sharpe_for_vn30f(y_pred, y_price, trade_threshold, fee_perc, periods):

    # Predict position base on change in future
    pos = [choose_position(roi, trade_threshold) for roi in y_pred]
    pos = np.array(pos)

    # Calculate PNL
    pnl = backtest_position_ps(pos, y_price, percentage=fee_perc, periods=periods)
    pnl = np.cumsum(pnl)

    # Standardalize PNL to date
    daily_pnl = [pnl.iloc[i] for i in range(0, len(pnl), 241)]
    daily_pnl = pd.Series(daily_pnl).fillna(0)

    # Calculate Sharpe
    sharpe = calculate_sharpe_ratio(daily_pnl)

    return pos, pnl, daily_pnl, sharpe

def calculate_hitrate(pos_predict, pos_true):
    if len(pos_predict) != len(pos_true):
        raise ValueError("Độ dài của hai mảng không khớp")

    # Tính số lượng dự đoán đúng (các phần tử tương ứng giống nhau)
    correct_predictions = np.sum(pos_predict == pos_true)

    # Tính tỷ lệ hit rate
    hit_rate_value = correct_predictions / len(pos_predict)

    return hit_rate_value

def scale_data(data):
    scaler = StandardScaler()
    data = np.where(np.isinf(data), np.nan, data)
    data = pd.DataFrame(data)
    data = data.fillna(0)
    scaler.fit(data)
    data=pd.DataFrame(scaler.transform(data), index=data.index, columns=data.columns)
    
    return data
def split_data(data):
    new_part = np.array_split(data, 3)

    # Access each part individually
    hold_out = new_part[2]
    train_data = pd.concat([new_part[0], new_part[1]], axis=0)

    return train_data, hold_out

def split_optuna_data(data):
        train_data, _ = split_data(data)
        optuna_data = train_data.drop(['close', 'open','high','low','volume', 'Return'], axis=1)
        optuna_data = scale_data(optuna_data)
        X_train, X_valid, y_train, y_valid = train_test_split(optuna_data, train_data['Return'], test_size=0.5, shuffle=False)

        return X_train, X_valid, y_train, y_valid

data = pd.read_csv('/kaggle/input/data-save1/save_data.csv')
data = data[data.Date >= '2021']
train_data, hold_out = split_data(data)

with open('/kaggle/input/newdata-1k-trials-feated/top_10_list.pkl', 'rb') as f:
    selected_columns_cluster = pickle.load(f)

min_delta = 0.0001
patience = 30

class CustomEarlyStopping:
    def __init__(self, min_delta, patience, verbose=False):
        self.min_delta = min_delta
        self.patience = patience
        self.verbose = verbose
        self.best_score = np.inf
        self.wait = 0
        self.stopped_epoch = 0

    def after_iteration(self, model, epoch, evals_log):
        if not evals_log:
            return False
        metric_name = next(iter(evals_log['validation_0']))
        score = evals_log['validation_0'][metric_name][-1]
        if score < (self.best_score - self.min_delta):
            self.best_score = score
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                if self.verbose:
                    print(f"\nStopping. Best score: {self.best_score}")
                self.stopped_epoch = epoch
                return True
        return False

    def get_best_score(self):
        return self.best_score
    
def objective_params(trial, X_train, X_valid, y_train, y_valid, y_close):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10)
    }
    trade_threshold = 0.005

    for t in trial.study.trials:
        if t.state != optuna.trial.TrialState.COMPLETE:
            continue
        if t.params == trial.params:
            return np.nan

    model = DecisionTreeRegressor(**params)
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_valid = model.predict(X_valid)

    pos, pnl, daily_pnl, sharpe_is = sharpe_for_vn30f(y_pred_train, y_close[:len(y_pred_train)], trade_threshold=trade_threshold, fee_perc=0.01, periods=10)
    _, _, _, sharpe_oos = sharpe_for_vn30f(y_pred_valid, y_close[len(y_pred_train):], trade_threshold=trade_threshold, fee_perc=0.01, periods=10)

    return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)

best_params_list = []
for idx, data_item in enumerate(selected_columns_cluster):
    train_cols, _ = split_data(data_item)
    optuna_data = scale_data(train_cols)

    X_train, X_valid, y_train, y_valid = train_test_split(optuna_data, train_data['Return'], test_size=0.5, shuffle=False)
    study = optuna.create_study(directions=['maximize', 'minimize'])

    unique_trials = 100
    while unique_trials > len(set(str(t.params) for t in study.trials)):
        study.optimize(lambda trial: objective_params(trial, X_train, X_valid, y_train, y_valid, train_data['Close']), n_trials=1)
        study.trials_dataframe().fillna(0).sort_values('values_0').to_csv(f'hypertuning{idx}.csv')
        joblib.dump(study, f'{unique_trials}hypertuningcluster{idx}.pkl')

    trials = study.trials
    completed_trials = [t for t in study.trials if t.values is not None]
    completed_trials.sort(key=lambda trial: trial.values, reverse=True)

    params = completed_trials[0].params
    best_params_list.append(params)

    model = DecisionTreeRegressor(**params)
    model.fit(X_train, y_train)

    with open(f'best_in_cluster_{idx}.pkl', 'wb') as f:
        pickle.dump(model, f)

with open('best_params_list.pkl', 'wb') as f:
    pickle.dump(best_params_list, f)
# Out:
# /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# [I 2024-07-05 04:03:55,345] A new study created in memory with name: no-name-72a15d1e-70ac-4a5c-893c-a312b46ba89f
# [I 2024-07-05 04:03:55,582] Trial 0 finished with values: [-0.5058502794424344, 1.8021928229515032] and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 10}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:03:55,789] Trial 1 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:03:56,352] Trial 2 finished with values: [1.0084991167806665, 1.9587614900632042] and parameters: {'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:03:56,553] Trial 3 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:03:56,954] Trial 4 finished with values: [1.1384574195049564, 1.2649013055871876] and parameters: {'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:03:57,263] Trial 5 finished with values: [-0.18533932950918475, 6.775045602279541] and parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:03:57,582] Trial 6 finished with values: [1.0333143909943945, 0.5419607730313278] and parameters: {'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:03:58,082] Trial 7 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:03:58,581] Trial 8 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:03:58,825] Trial 9 finished with values: [-0.6869224102739434, 1.4941758805918943] and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:03:59,369] Trial 10 finished with values: [1.0084991167806665, 1.849643537391767] and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:03:59,650] Trial 11 finished with values: [0.10437260582857993, 14.852135454181319] and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:00,205] Trial 12 finished with values: [-0.7973633460381007, 2.9648421738015527] and parameters: {'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 2}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:00,447] Trial 13 finished with values: [0.0, inf] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:00,654] Trial 14 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:01,021] Trial 15 finished with values: [1.0333143909943945, 0.4908306113821115] and parameters: {'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:01,452] Trial 16 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:01,992] Trial 17 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:02,529] Trial 18 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 4}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: invalid value encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [W 2024-07-05 04:04:02,737] Trial 19 failed with parameters: {'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 8} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:02,738] Trial 19 failed with value (0.0, nan).
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: invalid value encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [W 2024-07-05 04:04:02,951] Trial 20 failed with parameters: {'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 7} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:02,952] Trial 20 failed with value (0.0, nan).
# [I 2024-07-05 04:04:03,383] Trial 21 finished with values: [0.5278047471184986, 5.093161126588807] and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:03,628] Trial 22 finished with values: [-0.6869224102739434, 1.7165756526282072] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:04,134] Trial 23 finished with values: [-1.2300410106770843, 0.30206811495646324] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:04,677] Trial 24 finished with values: [1.028210730188136, 1.973821645591355] and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:05,108] Trial 25 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:05,544] Trial 26 finished with values: [-1.2300410106770843, 0.30206811495646324] and parameters: {'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:05,837] Trial 27 finished with values: [-0.5058502794424344, 1.8021928229515032] and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:06,172] Trial 28 finished with values: [-1.2049483839236712, 1.3834551445353855] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:06,677] Trial 29 finished with values: [0.02193388025929793, 142.0910683641936] and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:07,224] Trial 30 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:07,622] Trial 31 finished with values: [0.27678492027307505, 10.424783172170853] and parameters: {'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: invalid value encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [W 2024-07-05 04:04:07,839] Trial 32 failed with parameters: {'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 7} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:07,840] Trial 32 failed with value (0.0, nan).
# [I 2024-07-05 04:04:08,273] Trial 33 finished with values: [0.5803773169769041, 4.4275719186352775] and parameters: {'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:08,711] Trial 34 finished with values: [-1.211360304426882, 0.5679269484793742] and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:04:09,213] Trial 35 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:09,469] Trial 36 finished with values: [-0.6869224102739434, 1.1864140445441889] and parameters: {'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:09,910] Trial 37 finished with values: [0.03350339568379195, 99.09826870210695] and parameters: {'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:10,413] Trial 38 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:10,960] Trial 39 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:11,415] Trial 40 finished with values: [1.1094579241993905, 1.594615459406704] and parameters: {'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:11,637] Trial 41 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:12,079] Trial 42 finished with values: [0.8256242403923928, 2.7932995479871034] and parameters: {'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:12,373] Trial 43 finished with values: [-1.0609789580280853, 0.24581551441767213] and parameters: {'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:12,892] Trial 44 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 9}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: invalid value encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [W 2024-07-05 04:04:13,117] Trial 45 failed with parameters: {'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 7} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:13,118] Trial 45 failed with value (0.0, nan).
# [W 2024-07-05 04:04:13,152] Trial 46 failed with parameters: {'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:13,153] Trial 46 failed with value nan.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:13,378] Trial 47 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:13,945] Trial 48 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:14,351] Trial 49 finished with values: [-1.211360304426882, 0.5679269484793742] and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:04:14,651] Trial 50 finished with values: [-0.5058502794424344, 1.8099579653002613] and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:15,091] Trial 51 finished with values: [1.0333143909943945, 0.4908306113821115] and parameters: {'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:15,580] Trial 52 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:16,120] Trial 53 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:16,391] Trial 54 finished with values: [-0.5058502794424344, 1.8021928229515032] and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:16,803] Trial 55 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:17,251] Trial 56 finished with values: [-1.4111274824160567, 0.5465659198406005] and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:17,806] Trial 57 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:18,319] Trial 58 finished with values: [-1.2300410106770843, 0.30206811495646324] and parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:18,774] Trial 59 finished with values: [0.8604572636717887, 2.3186408501591735] and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:19,225] Trial 60 finished with values: [-1.2300410106770843, 0.30206811495646324] and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:19,601] Trial 61 finished with values: [0.9788260380214022, 1.6962408176435493] and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:19,868] Trial 62 finished with values: [-0.5058502794424344, 1.8099579653002613] and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:20,244] Trial 63 finished with values: [-1.7841349930819217, 0.3440686501797394] and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:20,766] Trial 64 finished with values: [-0.2716914963170209, 10.581539298780543] and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:21,341] Trial 65 finished with values: [-1.2300410106770843, 0.30206811495646324] and parameters: {'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:21,871] Trial 66 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:22,212] Trial 67 finished with values: [1.0333143909943945, 0.5419607730313278] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:22,663] Trial 68 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:23,225] Trial 69 finished with values: [0.45968663787742997, 5.143984399827551] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 1}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:23,464] Trial 70 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 4}.
# [W 2024-07-05 04:04:23,510] Trial 71 failed with parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:23,511] Trial 71 failed with value nan.
# [W 2024-07-05 04:04:23,558] Trial 72 failed with parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 4} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:23,559] Trial 72 failed with value nan.
# [I 2024-07-05 04:04:23,907] Trial 73 finished with values: [1.0333143909943945, 0.5419607730313278] and parameters: {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:24,215] Trial 74 finished with values: [-0.5058502794424344, 1.6862366652621246] and parameters: {'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:24,568] Trial 75 finished with values: [-0.43893636284383847, 3.52309248851829] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:24,955] Trial 76 finished with values: [0.1131995722114536, 24.995596736010402] and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:25,412] Trial 77 finished with values: [1.0333143909943945, 0.4908306113821115] and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 10}.
# [W 2024-07-05 04:04:25,460] Trial 78 failed with parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 7} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:25,461] Trial 78 failed with value nan.
# [I 2024-07-05 04:04:25,962] Trial 79 finished with values: [-0.7789132835349875, 2.1816426449156103] and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:26,383] Trial 80 finished with values: [-0.6510049503330847, 3.262340225064298] and parameters: {'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:26,661] Trial 81 finished with values: [-0.6869224102739434, 1.9243518783402394] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:27,195] Trial 82 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:27,692] Trial 83 finished with values: [-0.7789132835349875, 2.1816426449156103] and parameters: {'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:28,153] Trial 84 finished with values: [1.0333143909943945, 0.4908306113821115] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:28,617] Trial 85 finished with values: [0.3119653282891213, 9.097402955360973] and parameters: {'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:28,859] Trial 86 finished with values: [0.0, inf] and parameters: {'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 5}.
# [W 2024-07-05 04:04:28,911] Trial 87 failed with parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 6} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:28,912] Trial 87 failed with value nan.
# [I 2024-07-05 04:04:29,227] Trial 88 finished with values: [-0.5058502794424344, 1.8099579653002613] and parameters: {'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:29,691] Trial 89 finished with values: [0.9164266397097468, 1.9748272891248941] and parameters: {'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:30,256] Trial 90 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:30,831] Trial 91 finished with values: [0.4388491914141344, 6.870453214789963] and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:31,227] Trial 92 finished with values: [0.9788260380214022, 1.5085644512229037] and parameters: {'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:31,550] Trial 93 finished with values: [-0.5058502794424344, 1.734233083854067] and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:04:32,018] Trial 94 finished with values: [0.8256242403923928, 2.7932995479871034] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:32,591] Trial 95 finished with values: [0.23016632749669097, 13.770152091206695] and parameters: {'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:32,982] Trial 96 finished with values: [-1.453233096563544, 0.5207426744589985] and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:33,516] Trial 97 finished with values: [0.8256242403923928, 2.6158002043013613] and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 4}.
# [W 2024-07-05 04:04:33,573] Trial 98 failed with parameters: {'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:33,574] Trial 98 failed with value nan.
# [I 2024-07-05 04:04:33,896] Trial 99 finished with values: [-1.0609789580280853, 0.24581551441767213] and parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:34,326] Trial 100 finished with values: [1.0333143909943945, 0.4908306113821115] and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:34,867] Trial 101 finished with values: [-1.2300410106770843, 0.30206811495646324] and parameters: {'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 7}.
# [W 2024-07-05 04:04:34,928] Trial 102 failed with parameters: {'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 10} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:34,929] Trial 102 failed with value nan.
# [I 2024-07-05 04:04:35,465] Trial 103 finished with values: [-0.18533932950918475, 0.09464493360783988] and parameters: {'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:35,756] Trial 104 finished with values: [-0.6869224102739434, 1.9243518783402394] and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:36,242] Trial 105 finished with values: [1.0333143909943945, 0.4908306113821115] and parameters: {'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:36,818] Trial 106 finished with values: [-1.211360304426882, 0.5679269484793742] and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 8}.
# /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# [I 2024-07-05 04:04:37,229] A new study created in memory with name: no-name-ae5bb0c4-90f8-4225-97e3-71dff4558d92
# [I 2024-07-05 04:04:37,753] Trial 0 finished with values: [1.6097824909619165, 0.7631333353449363] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:38,146] Trial 1 finished with values: [-0.9354143466934856, 0.8328391781168858] and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:38,389] Trial 2 finished with values: [-0.9354143466934856, 0.28476057639262664] and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:38,707] Trial 3 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:39,174] Trial 4 finished with values: [0.5406979534422756, 3.1088274597619154] and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:39,418] Trial 5 finished with values: [0.41775020701009485, 2.101309555728721] and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:39,813] Trial 6 finished with values: [-0.8311267419792233, 1.4206456934665024] and parameters: {'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:40,239] Trial 7 finished with values: [-1.0804351881400258, 0.8009988464812481] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 3}.
# /tmp/ipykernel_18/1119175748.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   return sharpe_oos, abs((abs(sharpe_is / sharpe_oos)) - 1)
# [I 2024-07-05 04:04:40,558] Trial 8 finished with values: [0.0, inf] and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:40,836] Trial 9 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:41,381] Trial 10 finished with values: [0.5144234685219493, 4.482161861723042] and parameters: {'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:41,814] Trial 11 finished with values: [-1.3064817588772193, 0.6025502169805306] and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:42,352] Trial 12 finished with values: [0.9252918663652256, 0.2546671558810245] and parameters: {'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:42,862] Trial 13 finished with values: [-0.9057288324634297, 1.8334929889647156] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:04:43,107] Trial 14 finished with values: [-0.9354143466934856, 0.4091399582694737] and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:43,461] Trial 15 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:04:43,816] Trial 16 finished with values: [0.41775020701009485, 1.8789990991641061] and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:44,025] Trial 17 finished with values: [-0.9354143466934856, 0.28476057639262664] and parameters: {'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:44,351] Trial 18 finished with values: [0.41775020701009485, 2.3624702318106374] and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:44,824] Trial 19 finished with values: [0.35899332174900106, 2.8353193138486033] and parameters: {'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:04:45,185] Trial 20 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:45,509] Trial 21 finished with values: [0.41775020701009485, 2.3624702318106374] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:45,757] Trial 22 finished with values: [0.41775020701009485, 2.0881391759079824] and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:46,323] Trial 23 finished with values: [1.3323600840808927, 0.11486407806260779] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:46,540] Trial 24 finished with values: [-0.9354143466934856, 0.28476057639262664] and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:46,793] Trial 25 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:47,115] Trial 26 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:47,554] Trial 27 finished with values: [-1.2818186287065167, 0.5659155334925166] and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:47,915] Trial 28 finished with values: [0.41775020701009485, 2.8810874867028367] and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:48,435] Trial 29 finished with values: [0.1107918857227693, 26.572063581934618] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:48,800] Trial 30 finished with values: [-0.9354143466934856, 0.5838357667199718] and parameters: {'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:49,250] Trial 31 finished with values: [0.5504056945080393, 3.663606454799875] and parameters: {'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:49,687] Trial 32 finished with values: [0.14787427075052276, 15.772473117969628] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:50,205] Trial 33 finished with values: [1.3416864498099639, 1.0678346726468266] and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 3}.
# [W 2024-07-05 04:04:50,232] Trial 34 failed with parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:50,233] Trial 34 failed with value nan.
# [I 2024-07-05 04:04:50,572] Trial 35 finished with values: [-0.9354143466934856, 0.4063102789053423] and parameters: {'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:51,134] Trial 36 finished with values: [-1.1882112789281913, 0.477221212203522] and parameters: {'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:51,472] Trial 37 finished with values: [-0.9354143466934856, 0.44553009874466376] and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:04:51,883] Trial 38 finished with values: [-0.9354143466934856, 0.8328391781168858] and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:52,326] Trial 39 finished with values: [0.021346391811534852, 49.81401239994436] and parameters: {'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:04:52,844] Trial 40 finished with values: [-0.06215777822124924, 42.565121916414604] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:04:53,100] Trial 41 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 9}.
# [W 2024-07-05 04:04:53,131] Trial 42 failed with parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:53,132] Trial 42 failed with value nan.
# [I 2024-07-05 04:04:53,531] Trial 43 finished with values: [-1.2810984198437196, 0.22753672025901706] and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:53,864] Trial 44 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:54,121] Trial 45 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:54,382] Trial 46 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:54,755] Trial 47 finished with values: [-0.9354143466934856, 0.6631638136207358] and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 2}.
# [W 2024-07-05 04:04:54,788] Trial 48 failed with parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:04:54,789] Trial 48 failed with value nan.
# [I 2024-07-05 04:04:55,196] Trial 49 finished with values: [-0.6881420809411819, 1.5071603838655943] and parameters: {'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:55,460] Trial 50 finished with values: [-0.9354143466934856, 0.262820577790986] and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:55,802] Trial 51 finished with values: [0.41775020701009485, 1.8789990991641061] and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:04:56,308] Trial 52 finished with values: [0.4854217760015128, 1.6103240794189992] and parameters: {'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:56,690] Trial 53 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:57,182] Trial 54 finished with values: [-1.1882112789281913, 0.37744178547970275] and parameters: {'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:04:57,777] Trial 55 finished with values: [0.11607746068184231, 23.134922785554277] and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:58,159] Trial 56 finished with values: [-0.9354143466934856, 0.5838357667199718] and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:04:58,691] Trial 57 finished with values: [0.4854217760015128, 1.6103240794189992] and parameters: {'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:04:59,259] Trial 58 finished with values: [-0.17299782490743873, 15.305899072786744] and parameters: {'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:04:59,562] Trial 59 finished with values: [0.41775020701009485, 2.0881391759079824] and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:00,050] Trial 60 finished with values: [-0.4487507998823709, 4.866185483025691] and parameters: {'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# [W 2024-07-05 04:05:00,090] Trial 61 failed with parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:00,091] Trial 61 failed with value nan.
# [I 2024-07-05 04:05:00,363] Trial 62 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:00,897] Trial 63 finished with values: [0.1107918857227693, 26.29807322500875] and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:01,252] Trial 64 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [W 2024-07-05 04:05:01,295] Trial 65 failed with parameters: {'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 7} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:01,296] Trial 65 failed with value nan.
# [I 2024-07-05 04:05:01,793] Trial 66 finished with values: [0.5406979534422756, 3.1088274597619154] and parameters: {'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:05:02,330] Trial 67 finished with values: [-0.8514715828362074, 2.0140480885338063] and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 5}.
# [W 2024-07-05 04:05:02,374] Trial 68 failed with parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 4} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:02,375] Trial 68 failed with value nan.
# [I 2024-07-05 04:05:02,881] Trial 69 finished with values: [0.5406979534422756, 3.1088274597619154] and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:05:03,273] Trial 70 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:03,545] Trial 71 finished with values: [-0.9354143466934856, 0.28476057639262664] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 2}.
# [W 2024-07-05 04:05:03,591] Trial 72 failed with parameters: {'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 10} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:03,592] Trial 72 failed with value nan.
# [W 2024-07-05 04:05:03,639] Trial 73 failed with parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 9} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:03,640] Trial 73 failed with value nan.
# [I 2024-07-05 04:05:03,916] Trial 74 finished with values: [0.41775020701009485, 2.101309555728721] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:04,496] Trial 75 finished with values: [0.2031586594440015, 12.545141829852994] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2}.
# [W 2024-07-05 04:05:04,544] Trial 76 failed with parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:04,545] Trial 76 failed with value nan.
# [W 2024-07-05 04:05:04,594] Trial 77 failed with parameters: {'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 1} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:04,595] Trial 77 failed with value nan.
# [I 2024-07-05 04:05:05,139] Trial 78 finished with values: [-1.1882112789281913, 0.37744178547970275] and parameters: {'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 7}.
# [W 2024-07-05 04:05:05,187] Trial 79 failed with parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:05,188] Trial 79 failed with value nan.
# [I 2024-07-05 04:05:05,546] Trial 80 finished with values: [0.41775020701009485, 2.3624702318106374] and parameters: {'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:05,940] Trial 81 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:06,449] Trial 82 finished with values: [-0.14688308463229316, 13.799038996515698] and parameters: {'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:05:06,771] Trial 83 finished with values: [-0.9354143466934856, 0.3300299538197802] and parameters: {'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:05:07,244] Trial 84 finished with values: [-1.3725782249197682, 0.5253794560905094] and parameters: {'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:07,823] Trial 85 finished with values: [1.3323600840808927, 0.11486407806260779] and parameters: {'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:08,223] Trial 86 finished with values: [0.41775020701009485, 1.8789990991641061] and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:05:08,816] Trial 87 finished with values: [1.163702947583988, 1.55574865360443] and parameters: {'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 3}.
# [W 2024-07-05 04:05:08,870] Trial 88 failed with parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 4} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:08,871] Trial 88 failed with value nan.
# [I 2024-07-05 04:05:09,349] Trial 89 finished with values: [-0.14688308463229316, 13.781578267162065] and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:09,942] Trial 90 finished with values: [-1.1882112789281913, 0.477221212203522] and parameters: {'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:10,307] Trial 91 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:10,743] Trial 92 finished with values: [-1.0563118872234227, 1.0025991837268493] and parameters: {'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:11,281] Trial 93 finished with values: [0.35899332174900106, 2.8353193138486033] and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:11,567] Trial 94 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:11,933] Trial 95 finished with values: [-0.9354143466934856, 0.44553009874466376] and parameters: {'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:12,222] Trial 96 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:12,621] Trial 97 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:13,025] Trial 98 finished with values: [-0.9354143466934856, 0.5838357667199718] and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:05:13,391] Trial 99 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:13,681] Trial 100 finished with values: [0.41775020701009485, 2.101309555728721] and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:13,968] Trial 101 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:14,415] Trial 102 finished with values: [0.021346391811534852, 49.81401239994436] and parameters: {'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:15,008] Trial 103 finished with values: [-1.253779957999516, 1.003104489381193] and parameters: {'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 5}.
# [W 2024-07-05 04:05:15,068] Trial 104 failed with parameters: {'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:15,069] Trial 104 failed with value nan.
# [I 2024-07-05 04:05:15,442] Trial 105 finished with values: [-0.9354143466934856, 0.012481199601872772] and parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:15,982] Trial 106 finished with values: [-1.1882112789281913, 0.37744178547970275] and parameters: {'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:16,357] Trial 107 finished with values: [0.41775020701009485, 1.5866646241935598] and parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:16,766] Trial 108 finished with values: [0.658668121159571, 1.7561782872343428] and parameters: {'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:17,327] Trial 109 finished with values: [-1.1882112789281913, 0.37744178547970275] and parameters: {'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:17,890] Trial 110 finished with values: [-0.8514715828362074, 2.0140480885338063] and parameters: {'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:18,424] Trial 111 finished with values: [0.4854217760015128, 1.6103240794189992] and parameters: {'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:19,037] Trial 112 finished with values: [0.9252918663652256, 0.2546671558810245] and parameters: {'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 9}.
# /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# [I 2024-07-05 04:05:19,630] A new study created in memory with name: no-name-6536fa3f-3778-4674-b165-798eeda54e4a
# [I 2024-07-05 04:05:20,063] Trial 0 finished with values: [-0.4613551403220656, 3.5268359909938933] and parameters: {'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:05:20,390] Trial 1 finished with values: [0.012927641908521437, 113.24053581366897] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:20,793] Trial 2 finished with values: [0.4717473297806982, 3.3753866701783757] and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:21,036] Trial 3 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:21,539] Trial 4 finished with values: [0.5469259048161714, 4.196691720282796] and parameters: {'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:21,743] Trial 5 finished with values: [0.4288670207375603, 1.2109422615235843] and parameters: {'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:22,019] Trial 6 finished with values: [0.46796055485648586, 1.2525710523956097] and parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:22,554] Trial 7 finished with values: [0.5562069765444027, 3.710987746045044] and parameters: {'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:22,906] Trial 8 finished with values: [0.802525534221825, 0.850241180529828] and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:23,295] Trial 9 finished with values: [0.21582234179331267, 7.638207560221558] and parameters: {'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:05:23,538] Trial 10 finished with values: [0.4288670207375603, 1.224042567494172] and parameters: {'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:23,781] Trial 11 finished with values: [0.4288670207375603, 1.2260894793460255] and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:24,025] Trial 12 finished with values: [0.4288670207375603, 1.2260894793460255] and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:24,461] Trial 13 finished with values: [0.36952131382835834, 5.304461406479712] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:24,935] Trial 14 finished with values: [-0.3886997800350039, 5.270659947758324] and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:25,222] Trial 15 finished with values: [0.27402314674986594, 3.7520890392068065] and parameters: {'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 6}.
# ...
# [I 2024-07-05 04:05:33,712] Trial 36 finished with values: [0.669175534561278, 2.7902513112108402] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:34,147] Trial 37 finished with values: [0.669175534561278, 2.7902513112108402] and parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:34,441] Trial 38 finished with values: [0.4288670207375603, 1.2148244371927195] and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:34,703] Trial 39 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:34,998] Trial 40 finished with values: [0.4871257240552612, 1.7039441753558826] and parameters: {'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:35,251] Trial 41 finished with values: [0.4288670207375603, 1.2260894793460255] and parameters: {'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:35,761] Trial 42 finished with values: [0.5562069765444027, 3.710987746045044] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:36,332] Trial 43 finished with values: [-0.22644804195772114, 9.887372054017513] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 8}.
# [W 2024-07-05 04:05:36,364] Trial 44 failed with parameters: {'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 6} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:36,365] Trial 44 failed with value nan.
# [I 2024-07-05 04:05:36,923] Trial 45 finished with values: [-0.22644804195772114, 9.887372054017513] and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:37,262] Trial 46 finished with values: [0.6039691723668945, 1.992021276338971] and parameters: {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4}.
# [W 2024-07-05 04:05:37,297] Trial 47 failed with parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:37,298] Trial 47 failed with value nan.
# [I 2024-07-05 04:05:37,558] Trial 48 finished with values: [0.4288670207375603, 1.2109422615235843] and parameters: {'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:37,781] Trial 49 finished with values: [0.4288670207375603, 1.2148244371927195] and parameters: {'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:38,227] Trial 50 finished with values: [0.669175534561278, 2.7902513112108402] and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:38,558] Trial 51 finished with values: [0.5747530428606733, 1.5965238853321995] and parameters: {'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 7}.
# [W 2024-07-05 04:05:38,595] Trial 52 failed with parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 9} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:38,596] Trial 52 failed with value nan.
# [I 2024-07-05 04:05:38,969] Trial 53 finished with values: [0.02878801947632293, 50.47559440694363] and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:39,527] Trial 54 finished with values: [0.130946549988123, 22.77149016027394] and parameters: {'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:39,830] Trial 55 finished with values: [0.6000420719089183, 0.9832926709172509] and parameters: {'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:40,312] Trial 56 finished with values: [-0.3886997800350039, 5.270659947758324] and parameters: {'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:40,725] Trial 57 finished with values: [0.4079208192939128, 3.784855352259849] and parameters: {'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:41,065] Trial 58 finished with values: [0.802525534221825, 0.8654687572652198] and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:41,595] Trial 59 finished with values: [0.9841691833634456, 1.83524215859422] and parameters: {'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:42,043] Trial 60 finished with values: [-0.4613551403220656, 3.5268359909938933] and parameters: {'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 6}.
# [W 2024-07-05 04:05:42,083] Trial 61 failed with parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:42,084] Trial 61 failed with value nan.
# [W 2024-07-05 04:05:42,124] Trial 62 failed with parameters: {'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:42,125] Trial 62 failed with value nan.
# [I 2024-07-05 04:05:42,616] Trial 63 finished with values: [0.4880127210933724, 4.190426737258306] and parameters: {'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:42,848] Trial 64 finished with values: [0.4288670207375603, 1.2109422615235843] and parameters: {'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:43,377] Trial 65 finished with values: [-0.3886997800350039, 5.270659947758324] and parameters: {'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:43,644] Trial 66 finished with values: [0.4288670207375603, 1.2260894793460255] and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:43,918] Trial 67 finished with values: [0.4288670207375603, 1.224042567494172] and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:44,446] Trial 68 finished with values: [-0.22644804195772114, 9.887372054017513] and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:44,832] Trial 69 finished with values: [0.802525534221825, 0.8654687572652198] and parameters: {'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 8}.
# [W 2024-07-05 04:05:44,877] Trial 70 failed with parameters: {'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 5} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:44,878] Trial 70 failed with value nan.
# [W 2024-07-05 04:05:44,922] Trial 71 failed with parameters: {'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:44,923] Trial 71 failed with value nan.
# [I 2024-07-05 04:05:45,342] Trial 72 finished with values: [0.6229007779009165, 1.8638313629077823] and parameters: {'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:05:45,654] Trial 73 finished with values: [0.4288670207375603, 1.2191558324966532] and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:05:45,936] Trial 74 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:46,306] Trial 75 finished with values: [0.330830084295586, 2.4730227426184817] and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 3}.
# [I 2024-07-05 04:05:46,586] Trial 76 finished with values: [0.4288670207375603, 1.1723981321019439] and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 6}.
# [I 2024-07-05 04:05:46,904] Trial 77 finished with values: [0.6000420719089183, 0.9832926709172509] and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:47,178] Trial 78 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:47,451] Trial 79 finished with values: [0.4288670207375603, 1.2148244371927195] and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 2}.
# [W 2024-07-05 04:05:47,502] Trial 80 failed with parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 9} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:47,503] Trial 80 failed with value nan.
# [W 2024-07-05 04:05:47,553] Trial 81 failed with parameters: {'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 9} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:47,554] Trial 81 failed with value nan.
# [I 2024-07-05 04:05:47,906] Trial 82 finished with values: [0.6039691723668945, 1.992021276338971] and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:48,221] Trial 83 finished with values: [0.5761671631424757, 1.0376187576494216] and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:48,536] Trial 84 finished with values: [0.6000420719089183, 1.0137087641928475] and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 10}.
# [W 2024-07-05 04:05:48,589] Trial 85 failed with parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:48,590] Trial 85 failed with value nan.
# [W 2024-07-05 04:05:48,643] Trial 86 failed with parameters: {'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 5} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:48,644] Trial 86 failed with value nan.
# [I 2024-07-05 04:05:48,928] Trial 87 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}.
# [W 2024-07-05 04:05:48,982] Trial 88 failed with parameters: {'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 5} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:48,983] Trial 88 failed with value nan.
# [I 2024-07-05 04:05:49,231] Trial 89 finished with values: [0.4288670207375603, 1.2109422615235843] and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:49,909] Trial 90 finished with values: [0.8870371762160784, 2.167371132792016] and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:50,265] Trial 91 finished with values: [0.802525534221825, 0.8654687572652198] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:50,743] Trial 92 finished with values: [0.2548218413760427, 6.804653266936575] and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:51,027] Trial 93 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:51,581] Trial 94 finished with values: [-0.1972898592175909, 13.016178828204728] and parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:51,870] Trial 95 finished with values: [0.4288670207375603, 1.2260894793460255] and parameters: {'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:52,121] Trial 96 finished with values: [0.4288670207375603, 1.2260894793460255] and parameters: {'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 5}.
# [W 2024-07-05 04:05:52,179] Trial 97 failed with parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:52,180] Trial 97 failed with value nan.
# [I 2024-07-05 04:05:52,735] Trial 98 finished with values: [0.9784212784428636, 1.9622485130758882] and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 4}.
# [W 2024-07-05 04:05:52,793] Trial 99 failed with parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 7} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:52,794] Trial 99 failed with value nan.
# [I 2024-07-05 04:05:53,047] Trial 100 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:53,404] Trial 101 finished with values: [0.6039691723668945, 1.992021276338971] and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:53,921] Trial 102 finished with values: [0.06395824545696685, 28.400380783314304] and parameters: {'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:54,355] Trial 103 finished with values: [0.4531730861190497, 3.1734651048014078] and parameters: {'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 7}.
# [I 2024-07-05 04:05:54,864] Trial 104 finished with values: [0.4880127210933724, 4.190426737258306] and parameters: {'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 5}.
# [I 2024-07-05 04:05:55,266] Trial 105 finished with values: [0.4717473297806982, 3.3753866701783757] and parameters: {'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 5}.
# [W 2024-07-05 04:05:55,330] Trial 106 failed with parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:55,331] Trial 106 failed with value nan.
# [I 2024-07-05 04:05:55,734] Trial 107 finished with values: [0.34669687720438425, 3.6156184284775623] and parameters: {'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 10}.
# [I 2024-07-05 04:05:56,153] Trial 108 finished with values: [0.802525534221825, 0.850241180529828] and parameters: {'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 9}.
# [W 2024-07-05 04:05:56,217] Trial 109 failed with parameters: {'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 3} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:56,218] Trial 109 failed with value nan.
# [W 2024-07-05 04:05:56,283] Trial 110 failed with parameters: {'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 2} because of the following error: The value nan is not acceptable.
# [W 2024-07-05 04:05:56,283] Trial 110 failed with value nan.
# [I 2024-07-05 04:05:56,652] Trial 111 finished with values: [0.048283943556066765, 29.586994964937304] and parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 2}.
# [I 2024-07-05 04:05:57,133] Trial 112 finished with values: [0.3230340857858749, 6.340074608910491] and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1}.
# [I 2024-07-05 04:05:57,429] Trial 113 finished with values: [0.4288670207375603, 1.2198050123095503] and parameters: {'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 8}.
# [I 2024-07-05 04:05:57,804] Trial 114 finished with values: [0.802525534221825, 0.850241180529828] and parameters: {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 9}.
# [I 2024-07-05 04:05:58,059] Trial 115 finished with values: [0.4288670207375603, 1.224042567494172] and parameters: {'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 4}.
# [I 2024-07-05 04:05:58,501] Trial 116 finished with values: [0.6705980021269417, 1.8167707187110005] and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 9}.
